# %%
import Pkg

# %%
]activate
# Out:
#  Activating environment at `/mnt/c/Users/proteus/Documents/Stanford/tma-adp-base/Project.toml`

# %%
]instantiate

# %%
include("observations.jl")
include("mcts_utils.jl")
# Out:
# build_plot (generic function with 3 methods)

# %%
global_start_time = now()

#seed random number generator (rng)
rng = MersenneTwister(2)

#arguments = parse_commandline()

# set hyperparameters for trials
N = 500
DEPTH = 5
lambda = 0.9
num_runs = 5
iterations = 500
infile = false
c = 1
COLLISION_REWARD = -2
LOSS_REWARD = -2


df = CSV.read("run1_hist.csv", DataFrame)
start = df[!, 1]
hist = df

results_dir = string("../results/", global_start_time, "/")
mkdir(results_dir)
println("Writing results to: ", results_dir)

testing = false
epochsize = 500



println("starting state : ", start)



#output header file
header_string = string("MCTS Run: ", global_start_time)
header_string = string(header_string, "\n", "Depth: ", DEPTH)
header_string = string(header_string, "\n", "N: ", N)
header_string = string(header_string, "\n", "Lambda: ", lambda)
header_string = string(header_string, "\n", "Iterations: ", iterations)
header_string = string(header_string, "\n", "Collision Reward: ", COLLISION_REWARD)
header_string = string(header_string, "\n", "Loss Reward: ", LOSS_REWARD)
header_string = string(header_string, "\n", "start: ", start)
header_string = string(header_string, "\n", "hist: ", hist)
header_string = string(header_string, "\n", "c: ", c)

#write output header
header_filename = string(results_dir, global_start_time, "_header.txt")
open(header_filename, "w") do f
    write(f, header_string)
end



#cumulative collisions, losses, and number of trials
#total reward, and best average tracking
cum_coll = 0
cum_loss = 0
cum_trials = 0
total_reward = 0
best_average = 1


run_data = []

# trialslambda
num_particles = N
mcts_loss = 0
mcts_coll = 0
run_times = []
result = []
for i = 1:num_runs
    run_start_time = now()
    global mcts_loss, mcts_coll, num_particles, DEPTH, start, hist, result
    result = mcts_trial(DEPTH, c, num_particles, lambda, start=start, hist=hist)
    mcts_coll += result[3]
    mcts_loss += result[4]
    start = result[5]
    hist = result[7]
    #push!(run_data,result[5])
    push!(run_data,result[3:6])
    print(".")
    push!(run_times, (now()-run_start_time).value)
    CSV.write(string(results_dir, "run", i,"_hist.csv"), DataFrame([h for h in hist]))
    CSV.write(string(results_dir, "_run", i,"_start.csv"), DataFrame(transpose(start)))
    if i % 5 == 1 || i == num_runs
        println()
        println("==============================")
        println("Trials: ", i)
        println("NUM PARTICLES: ", num_particles)
        println("MCTS Depth ", DEPTH, " Results")
        println("Collision Rate: ", mcts_coll/i)
        println("Loss Rate: ", mcts_loss/i)
        println("==============================")
        namefile = string(results_dir, global_start_time, "_data.csv")
        updated_header = string(header_string, "\nAverage Runtime: ", mean(run_times))
        CSV.write(namefile, DataFrame(run_data))
        open(header_filename, "w") do f
            write(f, updated_header)
        end
    end
end
# Out:
# Writing results to: ../results/2021-09-19T12:52:27.116/
# starting state : [42, 201, 180, 1]
# Using starting state: [42, 201, 180, 1]
# random next state: Real[44.81363930186093, 250.37468914364803, 180, 2]
# random next state: Real[45.524368013196025, 201.99691254026015, 180, 1]
# random next state: Real[48.31904749142103, 249.33563332006864, 180, 2]
# random next state: Real[49.45744710115572, 203.91797596983758, 180, 2]
# random next state: Real[51.292110362268645, 246.98782821641242, 180, 1]
# random next state: Real[52.53750383012655, 206.02491078144885, 180, 2]
# random next state: Real[54.341796256216014, 244.90035478910502, 180, 1]
# random next state: Real[55.219893479394756, 206.9792116013766, 180, 1]
# random next state: Real[57.009456649991264, 243.93271825298743, 180, 1]
# random next state: Real[57.91618049432166, 207.84487939835645, 180, 1]
# random next state: Real[60.58503305708547, 243.48040157520217, 180, 2]
# random next state: Real[61.982698826475406, 209.001738823529, 180, 2]
# random next state: Real[63.739285103184876, 241.86994141244804, 180, 1]
# random next state: Real[64.70627698290711, 209.69201649845613, 210, 1]
# random next state: Real[67.45086047334033, 241.14497115073738, 210, 2]
# random next state: Real[68.80342079040855, 210.01516408695522, 210, 1]
# random next state: Real[71.54220617303605, 240.7863079330561, 210, 2]
# random next state: Real[73.41214177350261, 210.9758347061143, 210, 2]
# random next state: Real[76.13395671744551, 239.81166224126179, 210, 2]
# random next state: Real[77.51642313068147, 211.19475423548099, 210, 1]
# random next state: Real[80.2339885253981, 239.55990059005222, 210, 2]
# random next state: Real[81.62172233319635, 211.39165456540192, 240, 1]
# random next state: Real[84.20877066261366, 238.9913809407593, 240, 2]
# random next state: Real[86.25563649153693, 212.13565218821793, 240, 2]
# random next state: Real[87.98650788959435, 237.9063792779845, 210, 1]
# random next state: Real[89.95882297816657, 213.4710039766651, 210, 2]
# random next state: Real[91.79319414402785, 236.91103543109563, 210, 1]
# random next state: Real[93.23977526780155, 213.88195847113664, 210, 1]
# random next state: Real[95.90514905591706, 236.82461084644618, 210, 2]
# random next state: Real[97.35326891628921, 213.9335972282746, 210, 1]
# random next state: Real[100.01730423368099, 236.74529268981382, 210, 2]
# random next state: Real[102.0291236249854, 214.4467148305678, 180, 2]
# random next state: Real[103.68460055502547, 236.17843879903074, 150, 1]
# random next state: Real[104.89818089323094, 215.27425098846425, 150, 2]
# random next state: Real[106.96915172703903, 235.83098186784318, 150, 2]
# random next state: Real[108.19763184136156, 215.57358361632052, 150, 2]
# random next state: Real[110.25740226848636, 235.50423820404464, 150, 2]
# random next state: Real[110.91708368882517, 215.4365143457891, 150, 1]
# random next state: Real[112.98124988409606, 235.61284080019539, 150, 2]
# random next state: Real[114.21799855665009, 215.71538274429233, 150, 2]
# random next state: Real[115.45087852646142, 235.02670969735598, 150, 1]
# random next state: Real[116.71370902284282, 216.26698102552265, 180, 2]
# random next state: Real[118.33216217454155, 234.3058776813673, 210, 1]
# random next state: Real[120.42764921306876, 216.66278464154865, 210, 2]
# random next state: Real[123.03219961725688, 233.94739955125846, 210, 2]
# random next state: Real[124.54056654476825, 216.61129113799652, 210, 1]
# random next state: Real[126.33862018350747, 233.7113899099367, 210, 1]
# random next state: Real[127.85176445761934, 216.83005276684048, 210, 1]
# random next state: Real[130.45215820318685, 233.7487520637203, 210, 2]
# random next state: Real[132.5654567768377, 217.12243462952208, 210, 2]
# random next state: Real[133.95058230675846, 203.3246964960298, 210, 1]
# random next state: Real[135.93722280263538, 276.57731392491746, 150, 1]
# random next state: Real[134.17113297567585, 144.45153737658566, 180, 2]
# random next state: Real[135.80335918641939, 305.0578756745569, 180, 1]
# random next state: Real[134.1026351232473, 145.99139579879994, 180, 2]
# random next state: Real[135.76515086478543, 303.53651120007436, 180, 1]
# random next state: Real[134.13105744018088, 147.53171440913783, 180, 2]
# random next state: Real[135.82267856422305, 302.01536317488757, 180, 1]
# random next state: Real[134.25633837194957, 149.07026916287336, 180, 2]
# random next state: Real[135.60712229911522, 330.3432678713947, 150, 1]
# random next state: Real[133.7390281226719, 119.86614665500518, 150, 1]
# random next state: Real[135.10879660187993, 329.55319932009735, 150, 1]
# random next state: Real[132.38856615230176, 120.88879721538238, 150, 2]
# random next state: Real[134.30705633111995, 328.17142407635004, 180, 2]
# random next state: Real[131.7676657568983, 122.51654482043827, 180, 2]
# random next state: Real[133.40428237492858, 326.39690592008736, 180, 2]
# random next state: Real[130.9161369528628, 124.32975226182305, 180, 2]
# random next state: Real[132.0543756410949, 324.9536276853185, 180, 1]
# random next state: Real[129.60976230458277, 125.80794580637495, 180, 2]
# random next state: Real[131.38750055312894, 323.1310276648717, 180, 2]
# random next state: Real[129.79302834664307, 127.39869596726591, 150, 1]
# random next state: Real[131.94570000402274, 321.7444461575289, 150, 2]
# random next state: Real[129.39292847255672, 128.86748980970236, 150, 2]
# random next state: Real[130.9581533392308, 320.63412271164725, 150, 1]
# random next state: Real[128.43323661574834, 130.00440305057379, 150, 2]
# random next state: Real[130.02052263285853, 319.50735691402286, 150, 1]
# random next state: Real[127.52486345697339, 131.15797275152522, 150, 2]
# random next state: Real[129.8004341191961, 318.0347614496507, 150, 2]
# random next state: Real[128.08160557951018, 132.35710879039297, 150, 1]
# random next state: Real[129.7125047108905, 317.1826015579484, 150, 1]
# random next state: Real[127.28019730660642, 133.52918910438194, 150, 2]
# random next state: Real[128.93183031262612, 316.02261844589486, 150, 1]
# random next state: Real[126.53271422135224, 134.71561893288484, 150, 2]
# random next state: Real[128.20463353711173, 314.8489903640995, 150, 1]
# random next state: Real[125.84011726498986, 135.9156279156817, 150, 2]
# random next state: Real[127.53182918878208, 313.6624767596565, 150, 1]
# random next state: Real[125.8858085813612, 136.79481483410862, 120, 1]
# random next state: Real[128.30551542707144, 312.7227719793015, 120, 2]
# random next state: Real[125.97935712974312, 137.84531169068933, 120, 2]
# random next state: Real[127.67310090346574, 311.99102802375586, 120, 1]
# random next state: Real[125.36341421999144, 138.5934145317368, 120, 2]
# random next state: Real[127.81523228332692, 310.95654170869324, 120, 2]
# random next state: Real[126.17923986636916, 139.30008048697186, 120, 1]
# random next state: Real[128.64299572371638, 310.2662524694832, 120, 2]
# random next state: Real[127.01401149147185, 139.9975625822199, 90, 1]
# random next state: Real[128.42290787826005, 310.0574016265214, 90, 1]
# random next state: Real[127.01401149147186, 139.99756258221993, 90, 1]
# random next state: Real[129.18991089395362, 309.77198364680265, 90, 2]
# random next state: Real[127.14501398074029, 140.63244459905536, 90, 2]
# random next state: Real[128.55247462773698, 309.4294185258735, 90, 1]
# random next state: Real[127.14501398074029, 140.63244459905533, 90, 1]
# random next state: Real[128.55247462773698, 309.4294185258735, 90, 1]
# random next state: Real[126.51308326133679, 140.982568344865, 120, 2]
# random next state: Real[127.80615277004938, 338.75938556499403, 90, 1]
# random next state: Real[126.5130832613368, 110.98256834486502, 90, 1]
# random next state: Real[128.17182717960964, 338.3427262240069, 90, 2]
# random next state: Real[125.94410260133544, 111.57024537934667, 60, 2]
# random next state: Real[126.93338359076138, 338.36358308312913, 60, 1]
# random next state: Real[126.15082226963334, 111.35452622286425, 60, 1]
# random next state: Real[127.50818540043481, 338.1594219110542, 60, 2]
# random next state: Real[126.72339693995647, 111.56122609299246, 60, 1]
# random next state: Real[127.71265450271672, 338.37293627398543, 60, 1]
# random next state: Real[126.93018576057008, 111.34684610710006, 90, 1]
# random next state: Real[128.59833961237564, 337.98537370467795, 90, 2]
# random next state: Real[127.29760603196212, 111.76606386157289, 90, 1]
# random next state: Real[128.59833961237564, 337.98537370467795, 90, 1]
# random next state: Real[126.36944447188642, 111.93419253579201, 90, 2]
# random next state: Real[127.67180168590265, 337.81715356587074, 90, 1]
# random next state: Real[125.44238713767264, 112.10480774120238, 90, 2]
# random next state: Real[126.74638038377665, 337.64647546532586, 90, 1]
# random next state: Real[124.5164586930671, 112.27796195637909, 90, 2]
# random next state: Real[125.82210034430975, 337.4732882311294, 90, 1]
# random next state: Real[124.5164586930671, 112.27796195637909, 90, 1]
# random next state: Real[125.82210034430975, 337.4732882311294, 90, 1]
# random next state: Real[124.5164586930671, 112.27796195637909, 90, 1]
# random next state: Real[126.20859471252092, 337.05394561263, 90, 2]
# random next state: Real[123.97706612266094, 112.88082502658527, 90, 2]
# random next state: Real[125.28832896153541, 336.8756559530336, 90, 1]
# random next state: Real[123.97706612266096, 112.88082502658526, 90, 1]
# random next state: Real[125.68442154153284, 336.4564090532402, 90, 2]
# random next state: Real[124.36929431591408, 113.3052704452004, 90, 1]
# random next state: Real[125.68442154153284, 336.4564090532402, 90, 1]
# random next state: Real[123.45151827054622, 113.48888882062985, 90, 2]
# random next state: Real[125.174031880219, 335.8539336754885, 90, 2]
# random next state: Real[122.93999268839806, 114.10208219675663, 60, 2]
# random next state: Real[123.93474183899728, 335.8504128991328, 60, 1]
# random next state: Real[122.21184010397918, 114.06681593466264, 60, 2]
# random next state: Real[123.6184637742648, 335.46207054943875, 60, 2]
# random next state: Real[122.80533444170403, 114.26724848974295, 30, 1]
# random next state: Real[123.72998197439917, 335.3491969983877, 30, 2]
# random next state: Real[123.40031713835548, 114.4657506571883, 30, 1]
# random next state: Real[124.32779411487346, 335.15401331381497, 30, 2]
# random next state: Real[123.99676676883297, 114.66234549399823, 30, 1]
# random next state: Real[124.9270352498822, 334.96069989022567, 30, 2]
# random next state: Real[123.68801722801786, 115.05177686082946, 30, 2]
# random next state: Real[124.1977426572894, 334.9899029102673, 30, 1]
# random next state: Real[122.95871094890636, 115.02235357188407, 30, 2]
# random next state: Real[123.89410926827719, 334.6002518690424, 30, 2]
# random next state: Real[122.65528719141105, 115.41597078084916, 30, 2]
# random next state: Real[123.59623391005053, 334.2087044743281, 30, 2]
# random next state: Real[122.35768079263734, 115.81152149787366, 30, 2]
# random next state: Real[122.8661689411814, 334.23375787737706, 30, 1]
# random next state: Real[121.62759690985115, 115.78633437729297, 30, 2]
# random next state: Real[122.5737395887381, 333.8380529823556, 30, 2]
# random next state: Real[121.33549498859507, 116.18612644252794, 30, 2]
# random next state: Real[122.28718452236615, 333.4404745415642, 30, 2]
# random next state: Real[121.04932900823579, 116.58782839606673, 30, 2]
# random next state: Real[121.55646104027653, 333.4611817002975, 30, 1]
# random next state: Real[120.31858386446565, 116.56708009018315, 0, 2]
# random next state: Real[120.76914116493269, 333.00858581492844, 0, 2]
# random next state: Real[120.76914116493269, 116.99141418507156, 0, 1]
# random next state: Real[121.22627311057792, 332.58742900535975, 330, 2]
# random next state: Real[121.33859234375174, 117.65128563915701, 330, 1]
# random next state: Real[121.42825916876262, 331.765260283189, 330, 2]
# random next state: Real[121.54781228807133, 118.47226632352096, 330, 1]
# random next state: Real[121.17268181327648, 331.35933629382987, 330, 1]
# random next state: Real[120.42112125873057, 119.10806733957506, 330, 2]
# random next state: Real[120.5422171719717, 330.3053872470866, 330, 2]
# random next state: Real[120.67456365092788, 119.93234702115801, 330, 1]
# random next state: Real[120.81336736400031, 329.48326772727296, 330, 2]
# random next state: Real[120.09458315823042, 120.99695704458497, 330, 2]
# random next state: Real[119.735560677984, 328.82487146149606, 330, 1]
# random next state: Real[119.02849829748153, 121.66362186409896, 330, 2]
# random next state: Real[119.20450650530164, 327.74630020578684, 330, 2]
# random next state: Real[119.35906335044817, 122.49100017258361, 330, 1]
# random next state: Real[119.00990393730002, 327.3252889536455, 330, 1]
# random next state: Real[119.168085977188, 122.9118428850936, 330, 1]
# random next state: Real[119.37074692912533, 326.500815122684, 330, 2]
# random next state: Real[118.70567584577104, 124.00252827890408, 330, 2]
# random next state: Real[118.36673668568113, 325.808360850526, 330, 1]
# random next state: Real[117.71442713263109, 124.70312342295799, 330, 2]
# random next state: Real[117.38030958536832, 325.1041639302802, 330, 1]
# random next state: Real[117.5574753036775, 125.13306749898213, 0, 1]
# random next state: Real[117.5574753036775, 324.86693250101786, 0, 1]
# random next state: Real[117.5574753036775, 125.13306749898219, 0, 1]
# random next state: Real[117.55747530367752, 324.8669325010178, 0, 1]
# random next state: Real[116.7410760009741, 125.4155092708647, 0, 2]
# random next state: Real[117.32340837341248, 324.18649025598967, 0, 2]
# random next state: Real[117.32340837341248, 125.81350974401033, 0, 1]
# random next state: Real[117.32340837341248, 324.18649025598967, 0, 1]
# random next state: Real[117.32340837341248, 125.81350974401033, 330, 1]
# random next state: Real[117.58773723479572, 323.5958508343099, 330, 2]
# random next state: Real[116.97673889055814, 126.93089935885568, 330, 2]
# random next state: Real[117.26461948549026, 322.479405483501, 330, 2]
# random next state: Real[117.46385613470258, 127.75383098497679, 330, 1]
# random next state: Real[117.1512851467566, 322.04463937133363, 330, 1]
# random next state: Real[116.56979303292516, 128.49195182492286, 330, 2]
# random next state: Real[116.89038340290399, 320.9204459386384, 330, 2]
# random next state: Real[117.10253580252731, 129.3107844566344, 330, 1]
# random next state: Real[117.44014953023192, 320.1066162842985, 330, 2]
# random next state: Real[116.89607906434435, 130.43789492518107, 330, 2]
# random next state: Real[117.25705896397302, 318.98189583609565, 330, 2]
# random next state: Real[116.73500846694198, 131.56855443705626, 330, 2]
# random next state: Real[117.11928331407417, 317.8540936464703, 0, 2]
# random next state: Real[116.37977936586502, 132.47626337986532, 0, 2]
# random next state: Real[117.05738770399644, 317.1627240195501, 0, 2]
# random next state: Real[116.32608708853225, 133.17216804303317, 330, 2]
# random next state: Real[116.74314800242581, 316.2540430640401, 330, 2]
# random next state: Real[116.2753220763207, 134.31032697221687, 330, 2]
# random next state: Real[116.71544172945488, 315.1198710078058, 330, 2]
# random next state: Real[116.97418340330415, 135.09997260471098, 330, 1]
# random next state: Real[116.71700957687379, 314.67974335595807, 330, 1]
# random next state: Real[116.97918369057548, 135.53911411434353, 330, 1]
# random next state: Real[116.72546425775698, 314.23965349602344, 330, 1]
# random next state: Real[116.2983459217126, 136.33245567391464, 330, 2]
# random next state: Real[116.77898962475054, 313.1059269510227, 330, 2]
# random next state: Real[116.37501201579818, 137.46991079090412, 330, 2]
# random next state: Real[116.13665939443796, 312.3036295857285, 330, 1]
# random next state: Real[115.74918749244604, 138.2781057986036, 330, 2]
# random next state: Real[115.51735145146485, 311.49256924050445, 330, 1]
# random next state: Real[115.80391537678278, 138.72097896452294, 330, 1]
# random next state: Real[115.57566675286878, 311.04892671761166, 330, 1]
# random next state: Real[115.2141355822444, 139.53965468624216, 330, 2]
# random next state: Real[115.75784780258482, 309.9078160602974, 330, 2]
# random next state: Real[115.42002151464953, 140.68323323833306, 330, 2]
# random next state: Real[115.98578965686667, 308.7707408729924, 330, 2]
# random next state: Real[115.67171299347496, 141.82228739301684, 330, 2]
# random next state: Real[115.4689592779752, 307.9415904903089, 330, 1]
# random next state: Real[115.78163984353039, 142.26283013875494, 330, 1]
# random next state: Real[116.3774965509811, 307.2007957418659, 330, 2]
# random next state: Real[116.69547171664033, 143.00002692122982, 330, 1]
# random next state: Real[117.3051850676175, 306.4715975861284, 330, 2]
# random next state: Real[117.03944449529621, 144.12031856935778, 330, 2]
# random next state: Real[116.85595568381662, 305.64254407635576, 330, 1]
# random next state: Real[116.60780097729226, 144.95343483255115, 330, 2]
# random next state: Real[116.43137853408629, 304.80726815887556, 330, 1]
# random next state: Real[116.20099192042869, 145.79256290539237, 330, 2]
# random next state: Real[116.03172423719607, 303.96605843338114, 330, 1]
# random next state: Real[115.8192790141724, 146.63740435097293, 0, 2]
# random next state: Real[116.65578232251467, 303.09249239714353, 0, 2]
# random next state: Real[116.65578232251467, 146.90750760285644, 0, 1]
# random next state: Real[116.65578232251467, 303.09249239714353, 0, 1]
# random next state: Real[116.1128126332399, 147.32091816288968, 0, 2]
# random next state: Real[116.95576691859658, 302.41457162040587, 0, 2]
# random next state: Real[116.95576691859658, 147.58542837959416, 0, 1]
# random next state: Real[116.95576691859658, 302.41457162040587, 0, 1]
# random next state: Real[116.95576691859658, 147.58542837959416, 330, 1]
# random next state: Real[116.42278610238222, 331.999111359466, 300, 1]
# random next state: Real[115.51430126915287, 118.72947980677425, 300, 2]
# random next state: Real[114.9983982829313, 330.8446651795318, 300, 1]
# random next state: Real[114.12004373953948, 119.90196322958121, 300, 2]
# random next state: Real[113.6218565887243, 329.661756374141, 300, 1]
# random next state: Real[112.77474527463352, 121.10293307371447, 300, 2]
# random next state: Real[112.82137608031027, 328.01758189527607, 300, 2]
# random next state: Real[112.0181946389396, 122.76453599288978, 300, 2]
# random next state: Real[112.11508289024451, 326.35130429854394, 300, 2]
# random next state: Real[111.3570877556595, 124.44729838368211, 300, 2]
# random next state: Real[110.92941543982504, 325.0867099168706, 300, 1]
# random next state: Real[110.20620896016561, 125.72885866622256, 300, 2]
# random next state: Real[110.3925571745493, 323.37662854378203, 300, 2]
# random next state: Real[109.71684517661468, 127.45365866740339, 300, 2]
# random next state: Real[109.95494738344607, 321.6513871318223, 270, 2]
# random next state: Real[109.80012744381855, 129.0816291778864, 270, 1]
# random next state: Real[109.66332805118218, 320.18340515120656, 270, 1]
# random next state: Real[108.78675776705896, 130.89570030158586, 270, 2]
# random next state: Real[109.36168486727152, 317.9691780737882, 270, 2]
# random next state: Real[109.2975555517634, 132.77120393153203, 270, 1]
# random next state: Real[109.94259911940618, 316.1097195863976, 270, 2]
# random next state: Real[109.21487191467111, 134.99583275517386, 270, 2]
# random next state: Real[109.94229258514514, 313.89855820620875, 270, 2]
# random next state: Real[109.97856714587648, 136.83809195036756, 270, 1]
# random next state: Real[110.03300761154564, 312.42586524640996, 270, 1]
# random next state: Real[109.44302586391709, 138.700269284411, 270, 2]
# random next state: Real[109.54338612089926, 310.5615593897004, 270, 1]
# random next state: Real[109.02415598866145, 140.57875417083073, 270, 2]
# random next state: Real[109.9531083716128, 308.356835678773, 300, 2]
# random next state: Real[109.71475991639264, 142.53811667335233, 300, 2]
# random next state: Real[109.58937895294859, 306.9434814112903, 300, 1]
# random next state: Real[109.39350338955306, 143.95707870137076, 300, 2]
# random next state: Real[109.29275420281338, 305.5215858140439, 300, 1]
# random next state: Real[109.13971242127636, 145.38351865584525, 300, 2]
# random next state: Real[109.8933416444801, 303.8005852885767, 300, 2]
# random next state: Real[110.3384866233337, 146.66534409210232, 300, 1]
# random next state: Real[111.1265739701096, 302.53658140543206, 300, 2]
# random next state: Real[111.59128387327812, 147.91900430107097, 300, 1]
# random next state: Real[111.55944772682072, 301.56773788423664, 300, 1]
# random next state: Real[112.03901830198761, 148.88197433344, 300, 1]
# random next state: Real[112.88579909497051, 300.3482379720012, 300, 2]
# random next state: Real[112.88855966109065, 150.53087025919714, 300, 2]
# random next state: Real[112.9022532786881, 298.9616636135055, 300, 1]
# random next state: Real[112.94691745269435, 151.91686229790446, 300, 2]
# random next state: Real[112.98478728010377, 297.5763042968593, 300, 1]
# random next state: Real[113.07127674615757, 153.30061421232287, 300, 2]
# random next state: Real[114.03141715120093, 295.97198538326296, 300, 2]
# random next state: Real[114.5940122664203, 154.44239138674712, 300, 1]
# random next state: Real[115.5824477221203, 294.84950643225, 300, 2]
# random next state: Real[115.7507926303658, 156.00441571982066, 300, 2]

# %%
df = CSV.read("run1_hist.csv", DataFrame)
# Out:
# 4×501 DataFrame
#  Row │ x1     x2       x3        x4        x5        x6        x7        x8    ⋯
#      │ Int64  Float64  Float64   Float64   Float64   Float64   Float64   Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    42   43.873   44.5987   46.4531   47.6361   50.3732   51.2022   53.0 ⋯
#    2 │   201  249.936  202.478   248.465   204.893   246.543   205.51    245.4
#    3 │   180  180.0    180.0     180.0     180.0     180.0     180.0     180.0
#    4 │     1    1.0      1.0       1.0       2.0       2.0       1.0       1.0
#                                                              494 columns omitted

# %%
# Out:
# 4×501 DataFrame
#  Row │ x1     x2       x3        x4        x5        x6        x7        x8    ⋯
#      │ Int64  Float64  Float64   Float64   Float64   Float64   Float64   Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    42   43.873   44.5987   46.4531   47.6361   50.3732   51.2022   53.0 ⋯
#    2 │   201  249.936  202.478   248.465   204.893   246.543   205.51    245.4
#    3 │   180  180.0    180.0     180.0     180.0     180.0     180.0     180.0
#    4 │     1    1.0      1.0       1.0       2.0       2.0       1.0       1.0
#                                                              494 columns omitted

# %%
start = df[!, 1]
# Out:
# 4×501 DataFrame
#  Row │ x1     x2       x3        x4        x5        x6        x7        x8    ⋯
#      │ Int64  Float64  Float64   Float64   Float64   Float64   Float64   Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │    42   43.873   44.5987   46.4531   47.6361   50.3732   51.2022   53.0 ⋯
#    2 │   201  249.936  202.478   248.465   204.893   246.543   205.51    245.4
#    3 │   180  180.0    180.0     180.0     180.0     180.0     180.0     180.0
#    4 │     1    1.0      1.0       1.0       2.0       2.0       1.0       1.0
#                                                              494 columns omitted
